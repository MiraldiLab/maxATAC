# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_table("/Users/caz3so/scratch/20210818_maxATAC_MOOD_ENCODE_publication/peaks/A549_ext40_peaks.narrowPeak", header=None)

# %%
df
# Out:
#            0          1          2  \
# 0       chr1      10035      10141
# 1       chr1      29297      29337
# 2       chr1     181385     181505
# 3       chr1     181815     181857
# 4       chr1     184495     184535
# ...      ...        ...        ...
# 303817  chr9  138129670  138129761
# 303818  chr9  138132284  138132357
# 303819  chr9  138149960  138150033
# 303820  chr9  138182203  138182243
# 303821  chr9  138211932  138212111
#
#                                                         3    4  5         6  \
# 0       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...  147  .   7.84138
# 1       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...   52  .   4.57414
# 2       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...   29  .   3.59396
# 3       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...  106  .   6.53448
# 4       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...   52  .   4.57414
# ...                                                   ...  ... ..       ...
# ...

# %%
df["length"] = df[2] - df[1]

# %%
df
# Out:
#            0          1          2  \
# 0       chr1      10035      10141
# 1       chr1      29297      29337
# 2       chr1     181385     181505
# 3       chr1     181815     181857
# 4       chr1     184495     184535
# ...      ...        ...        ...
# 303817  chr9  138129670  138129761
# 303818  chr9  138132284  138132357
# 303819  chr9  138149960  138150033
# 303820  chr9  138182203  138182243
# 303821  chr9  138211932  138212111
#
#                                                         3    4  5         6  \
# 0       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...  147  .   7.84138
# 1       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...   52  .   4.57414
# 2       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...   29  .   3.59396
# 3       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...  106  .   6.53448
# 4       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...   52  .   4.57414
# ...                                                   ...  ... ..       ...
# ...

# %%
plt.hist(df["length"])
# Out:
# (array([2.67527e+05, 2.25650e+04, 8.48600e+03, 3.55400e+03, 1.25100e+03,
#         3.48000e+02, 7.00000e+01, 1.50000e+01, 5.00000e+00, 1.00000e+00]),
#  array([  40. ,  267.9,  495.8,  723.7,  951.6, 1179.5, 1407.4, 1635.3,
#         1863.2, 2091.1, 2319. ]),
#  <BarContainer object of 10 artists>)

# %%
np.mean(df["length"])
# Out:
# 144.91925535346354

# %%
plt.hist(df[9])
# Out:
# (array([2.7691e+05, 1.8414e+04, 5.5000e+03, 1.9750e+03, 6.9100e+02,
#         2.2800e+02, 7.2000e+01, 2.2000e+01, 4.0000e+00, 6.0000e+00]),
#  array([   0. ,  163.8,  327.6,  491.4,  655.2,  819. ,  982.8, 1146.6,
#         1310.4, 1474.2, 1638. ]),
#  <BarContainer object of 10 artists>)

# %%
np.log(.1)
# Out:
# -2.3025850929940455

# %%
-np.log(.05)
# Out:
# 2.995732273553991

# %%
df[df[8] >= -np.log(.05)]
# Out:
#            0          1          2  \
# 0       chr1      10035      10141
# 1       chr1      29297      29337
# 3       chr1     181815     181857
# 4       chr1     184495     184535
# 6       chr1     191393     191562
# ...      ...        ...        ...
# 303810  chr9  138068819  138068871
# 303814  chr9  138113545  138114125
# 303816  chr9  138129489  138129536
# 303817  chr9  138129670  138129761
# 303821  chr9  138211932  138212111
#
#                                                         3    4  5         6  \
# 0       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...  147  .   7.84138
# 1       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...   52  .   4.57414
# 3       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...  106  .   6.53448
# 4       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...   52  .   4.57414
# 6       /data/miraldiNB/Tareian/scratch/20210803_v1_AT...   69  .   5.22759
# ...                                                   ...  ... ..       ...
# ...
